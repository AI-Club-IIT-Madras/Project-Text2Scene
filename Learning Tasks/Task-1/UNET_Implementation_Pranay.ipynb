# %%
import torch
import torch.nn as nn
import torchvision.transforms.functional as TF
from sklearn.model_selection import train_test_split
import os

# %%
# Define the folder name
folder_name = 'Predictions'

# Specify the path where you want to create the folder
folder_path = '/content/' + folder_name

# Create the folder
os.makedirs(folder_path, exist_ok=True)

# %%
# !gdown 'https://drive.google.com/uc?id=1mrN0MYL9uwjzw_jZmvlb4-lCnmBM3b7A'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1mrN0MYL9uwjzw_jZmvlb4-lCnmBM3b7A
# To: /content/Forest.zip
# 100% 181M/181M [00:01<00:00, 166MB/s]

# %%
# !unzip '/content/Forest.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Forest Segmented/Forest Segmented/masks/119079_mask_73.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/119079_mask_77.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/119079_mask_78.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/119079_mask_80.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/119079_mask_81.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/119079_mask_87.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/119079_mask_88.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_00.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_01.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_11.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_16.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_20.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_21.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_22.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_24.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_25.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_30.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_31.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_32.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_34.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_42.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_43.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_53.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_54.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_55.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_56.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_57.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_63.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_64.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_65.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_73.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_74.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_80.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_81.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_84.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_85.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_86.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_87.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122104_mask_88.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_01.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_02.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_05.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_06.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_07.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_11.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_12.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_16.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_17.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/122178_mask_18.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_30.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_31.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_32.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_33.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_34.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_35.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_42.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_43.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_46.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_56.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_57.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_63.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_66.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_67.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_68.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_76.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_77.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_78.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_80.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_81.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_87.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/126796_mask_88.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_00.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_02.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_08.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_10.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_12.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_18.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_20.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_24.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_25.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_27.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_28.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_30.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_33.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_43.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_53.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/133209_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_00.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_01.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_02.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_05.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_06.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_07.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_08.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_10.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_12.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_16.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_17.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_21.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_22.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_24.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_27.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_32.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_33.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_34.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_35.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_38.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_43.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_44.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_45.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_47.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_48.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_54.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_58.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_66.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_67.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_68.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_78.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/13415_mask_80.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_05.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_16.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_17.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_18.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_24.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_33.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_34.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_35.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_42.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_43.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_44.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_53.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_54.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_58.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_63.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_64.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_65.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_66.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_67.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_68.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_73.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_74.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_75.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_76.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_81.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_83.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_84.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_85.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/134465_mask_86.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_24.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_25.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_27.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_33.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_35.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_38.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_42.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_43.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/143794_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_02.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_05.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_06.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_07.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_08.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_10.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_11.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_12.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_16.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_20.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_21.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_22.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_30.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_31.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/147716_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_07.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_08.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_17.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_18.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_20.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_21.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_24.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_30.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_31.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_32.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_33.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_43.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_46.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_53.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_54.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_56.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_63.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_64.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_66.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_74.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_75.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_77.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_81.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_84.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_85.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_86.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/148381_mask_87.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_02.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_05.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_06.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_07.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_16.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_25.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_35.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/152569_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_00.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_01.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_02.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_06.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_07.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_10.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_11.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_12.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_16.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_17.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_20.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_21.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_22.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_27.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_31.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_32.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_38.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_42.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_43.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_44.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_47.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_48.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_54.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_56.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_57.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_58.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_63.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_66.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_67.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_68.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_73.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_75.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_76.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_77.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_78.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_83.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_84.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_85.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_86.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/15573_mask_87.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_00.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_01.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_02.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_10.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_11.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_12.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_16.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_17.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_20.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_22.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_24.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_25.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_27.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_35.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_38.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_45.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_46.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_47.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_48.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_53.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_54.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_56.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_57.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_58.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_64.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_67.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_68.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_78.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/156574_mask_80.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_00.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_01.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_06.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_07.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_08.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_11.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_12.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_17.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_18.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_24.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_25.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_28.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_34.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_35.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_47.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_48.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_56.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_58.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_65.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_66.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/162310_mask_80.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_00.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_10.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_16.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_17.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_18.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_20.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_22.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_24.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_25.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_30.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_31.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_32.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_46.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_47.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_48.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_53.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_54.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_55.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_56.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_57.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_58.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_63.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_64.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_67.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_68.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_73.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_74.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_77.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_78.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_80.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_81.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_87.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/170535_mask_88.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/172307_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/172307_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/172307_mask_88.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_00.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_01.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_05.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_06.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_08.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_11.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_22.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_24.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_27.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_28.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_32.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_33.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_34.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_38.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_48.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_63.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_73.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_80.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_81.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/174980_mask_88.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_10.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_20.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_27.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_28.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_30.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_31.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_47.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_53.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_54.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_55.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_56.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_57.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_63.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_64.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_65.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_66.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_67.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_73.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_74.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_75.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_77.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_83.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_84.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/176225_mask_87.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_01.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_02.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_05.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_07.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_08.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_11.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_12.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_16.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_17.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_20.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_21.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_22.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_24.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_25.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_27.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_30.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_31.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_35.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_46.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_47.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_56.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_57.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_58.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_66.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_67.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_76.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_77.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/182422_mask_87.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_00.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_01.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_02.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_06.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_07.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_08.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_10.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_11.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_16.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_20.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_24.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_30.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_31.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_38.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_48.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_58.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_67.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_68.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_73.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_74.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_75.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_76.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_77.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_80.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_83.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_84.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_85.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/192918_mask_86.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/195769_mask_06.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/195769_mask_07.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/195769_mask_08.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/195769_mask_17.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/195769_mask_18.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/20187_mask_04.jpg
# ...
#   inflating: Forest Segmented/Forest Segmented/masks/940229_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/940229_mask_73.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/940229_mask_74.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/940229_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/940229_mask_83.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/940229_mask_84.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_06.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_07.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_08.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_16.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_18.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_27.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_28.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_33.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_34.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_35.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_38.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_43.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_44.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_53.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_63.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/943943_mask_88.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/949559_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/949559_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/949559_mask_80.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/949559_mask_81.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/949559_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/949559_mask_83.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_05.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_14.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_30.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_31.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_32.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_33.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_34.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_42.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_43.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_44.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_45.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_53.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_55.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_63.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_64.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_65.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_66.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_67.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_73.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_74.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_75.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_76.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_77.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_78.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_81.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_85.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/950926_mask_87.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/952430_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/952430_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/952430_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/952430_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/952430_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/952430_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/952430_mask_81.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/952430_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/952430_mask_83.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_05.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_15.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_25.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_34.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_35.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_44.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_45.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_46.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_47.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_54.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_55.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_56.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_57.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_58.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_64.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_68.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/961407_mask_78.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/967818_mask_18.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/967818_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/967818_mask_27.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/967818_mask_28.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/967818_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/967818_mask_46.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/967818_mask_47.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/967818_mask_48.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/96870_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/96870_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/96870_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/96870_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/96870_mask_83.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/96870_mask_84.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/96870_mask_85.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/96870_mask_86.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/96870_mask_87.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/96870_mask_88.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_30.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_42.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_67.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_68.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_75.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_76.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_77.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_84.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_85.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/978039_mask_86.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_01.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_02.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_11.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_12.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_42.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_60.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_61.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_62.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_70.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_71.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981253_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981852_mask_10.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981852_mask_11.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981852_mask_12.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981852_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981852_mask_23.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981852_mask_33.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981852_mask_42.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981852_mask_43.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981852_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981852_mask_51.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/981852_mask_52.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_06.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_07.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_26.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_27.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_36.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_53.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_65.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_66.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_67.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_68.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_72.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_74.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_75.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_76.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_77.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_78.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_80.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_81.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_82.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/986342_mask_84.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/992507_mask_37.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/992507_mask_38.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/992507_mask_47.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/992507_mask_56.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/992507_mask_57.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/992507_mask_66.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/992507_mask_75.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/992507_mask_76.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/992507_mask_85.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/998002_mask_00.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/998002_mask_03.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/998002_mask_04.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/998002_mask_12.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/998002_mask_13.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/998002_mask_22.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/998002_mask_31.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/998002_mask_32.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/998002_mask_40.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/998002_mask_41.jpg
#   inflating: Forest Segmented/Forest Segmented/masks/998002_mask_50.jpg
#   inflating: Forest Segmented/Forest Segmented/meta_data.csv
#   inflating: meta_data.csv

# %%
# Importing the required libraries
import os
import shutil

# Define the path of the input directory
input_dir_path = '/content/Forest Segmented/Forest Segmented/images'  # Replace with your directory path

# Define the paths for the output directories
output_dir1_path = '/content/Forest Segmented/Forest Segmented/train_images'
output_dir2_path = '/content/Forest Segmented/Forest Segmented/test_images'


# Create the output directories
os.makedirs(output_dir1_path, exist_ok=True)
os.makedirs(output_dir2_path, exist_ok=True)

# Get the list of files in the input directory
files = os.listdir(input_dir_path)

# Sort the files to maintain consistency across runs
files.sort()

# Split the files into two parts
part1 = files[0:49]
part2 = files[50:19]

# Move the files to the output directories
for file in part1:
    src_path = os.path.join(input_dir_path, file)
    dst_path = os.path.join(output_dir1_path, file)
    shutil.move(src_path, dst_path)

for file in part2:
    src_path = os.path.join(input_dir_path, file)
    dst_path = os.path.join(output_dir2_path, file)
    shutil.move(src_path, dst_path)

# %%
# Define the path of the input directory
input_dir_path = '/content/Forest Segmented/Forest Segmented/masks'  # Replace with your directory path

# Define the paths for the output directories
output_dir1_path = '/content/Forest Segmented/Forest Segmented/train_masks'
output_dir2_path = '/content/Forest Segmented/Forest Segmented/test_masks'


# Create the output directories
os.makedirs(output_dir1_path, exist_ok=True)
os.makedirs(output_dir2_path, exist_ok=True)

# Get the list of files in the input directory
files = os.listdir(input_dir_path)

# Sort the files to maintain consistency across runs
files.sort()

# Split the files into two parts
part1 = files[0:49]
part2 = files[50:59]

# Move the files to the output directories
for file in part1:
    src_path = os.path.join(input_dir_path, file)
    dst_path = os.path.join(output_dir1_path, file)
    shutil.move(src_path, dst_path)

for file in part2:
    src_path = os.path.join(input_dir_path, file)
    dst_path = os.path.join(output_dir2_path, file)
    shutil.move(src_path, dst_path)

# %%
#creating a class to do the successive colvolutions
class DoubleConv(nn.Module):
  def __init__(self, in_channels, out_channels):
    super(DoubleConv, self).__init__()
    self.conv = nn.Sequential(      #creates a sequence of convolution operations 
        nn.Conv2d(in_channels, out_channels, 3, 1, 1, bias=False),    #kernel_size, stride, padding : results in same convolution, no bias (b) term
        nn.BatchNorm2d(out_channels),
        nn.ReLU(inplace=True),
        nn.Conv2d(out_channels, out_channels, 3, 1, 1, bias=False),
        nn.BatchNorm2d(out_channels),
        nn.ReLU(inplace=True),
    )

  def forward (self, x):
    return self.conv(x)

# %%
class UNET(nn.Module):

  def __init__(self, in_channels = 3, out_channels = 1, features = [64, 128, 256, 512]):    #in_channels = 3 as RGB, features: number of channels in successive layers
    super(UNET, self).__init__()
    self.ups = nn.ModuleList()    #special list which stores instances of nn.Module
    self.downs = nn.ModuleList()
    self.pool = nn.MaxPool2d(kernel_size = 2, stride = 2)

    #down part of UNET
    for feature in features:
      self.downs.append (DoubleConv(in_channels, feature))
      in_channels = feature

    #up part of UNET
    for feature in reversed(features):
      self.ups.append (nn.ConvTranspose2d(feature*2, feature, kernel_size = 2, stride = 2))
      self.ups.append (DoubleConv (feature*2 , feature))

    #bottommost part
    self.bottleneck = DoubleConv (features[-1], features[-1]*2)

    #last layer
    self.final_conv = nn.Conv2d (features[0], out_channels, kernel_size = 1)    

  
  def forward (self, x):
    skip_connections = []

    for down in self.downs:
      x = down(x)
      skip_connections.append(x)
      x = self.pool (x)

    x = self.bottleneck (x)
    skip_connections = skip_connections[::-1]

    #doing Transposed convolution then double conv repeatedly
    for idx in range (0, len(self.ups), 2):     #self.ups contains the 2dconv as well as Transpose2D tesnors
      x = self.ups[idx](x)    #contains the Transposed Convolution function
      skip_connection = skip_connections [idx//2]

      if x.shape != skip_connection.shape:    #happens if skip connection has odd size, x would have 1 pixel less as pooling floors
        x = TF.resize (x, size = skip_connection.shape[2:])   #skip batch size, number of channels

      concat_skip = torch.cat ((skip_connection, x), dim = 1)   #join along 1 dimension (vertical join)
      x =  self.ups[idx+1](concat_skip)   #contains the double conv

    return self.final_conv(x)

# %%
#Dataset loading
import os
from PIL import Image
from torch.utils.data import Dataset
import numpy as np

# %%
class ImageDataset(Dataset):
  def __init__(self, image_dir, mask_dir, transform=None):    #transform = None as a standard
    self.image_dir = image_dir
    self.mask_dir = mask_dir
    self.transform = transform 
    self.images = os.listdir(image_dir)

  def __len__(self):    #dunder methods (double underscore) - invoked automatically when an instance created
    return (len(self.images))
  
  def __getitem__(self, index):
    img_path = os.path.join (self.image_dir, self.images[index])
    path1 = self.images[index]
    path2 = path1[-7::1]
    path3 = path1[-11::-1]
    path4 = path3[-1::-1]
    path1 = path4 + 'mask' + path2
    mask_path = os.path.join (self.mask_dir, path1)
    image = np.array(Image.open(img_path).convert("RGB"))
    #mask_path = os.path.join (self.mask_dir, self.images[index].replace(".jpg", "_mask.gif"))

    if os.path.exists(mask_path):
        mask = np.array(Image.open(mask_path).convert("L"), dtype=np.float32)
        mask[mask == 255.0] = 1.0
    else:
        # If the mask file is missing, skip this element or handle it as desired
        # In this example, we assign a default mask
        mask = np.zeros_like(image[:, :, 0], dtype=np.float32)    
    
    mask = np.array(Image.open(mask_path).convert("L"), dtype = np.float32)
    mask[mask == 255.0 ] = 1.0

    if self.transform is not None:
      augmentations = self.transform(image = image, mask = mask)
      image = augmentations ['image']
      mask = augmentations ['mask']
    
    return image, mask

# %%
#training
import albumentations as A
from tqdm import tqdm
from albumentations.pytorch import ToTensorV2
import torch.optim as optim
import torchvision
from torch.utils.data import DataLoader

# %%
#Hyperparameters
LEARNING_RATE = 1e-4
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
BATCH_SIZE = 8
NUM_EPOCHS = 3
NUM_WORKERS = 2
IMAGE_HEIGHT = 160
IMAGE_WIDTH = 240 
PIN_MEMORY = True
LOAD_MODEL = True
TRAIN_IMG_DIR = '/content/Forest Segmented/Forest Segmented/train_images'
TRAIN_MASK_DIR = '/content/Forest Segmented/Forest Segmented/train_masks'
VAL_IMG_DIR = '/content/Forest Segmented/Forest Segmented/test_images'
VAL_MASK_DIR = '/content/Forest Segmented/Forest Segmented/test_masks'

# %%
def train_fn(loader, model, optimizer, loss_fn, scaler):
  loop = tqdm (loader)
  

  for batch_idx, (data, targets) in enumerate(loop):
    data = data.to(device = DEVICE)
    targets = targets.float().unsqueeze(1).to(device = DEVICE)

    #forward
    with torch.cuda.amp.autocast():
      predictions = model(data)
      loss = loss_fn (predictions, targets)

    #backward
    optimizer.zero_grad()
    scaler.scale(loss).backward()
    scaler.step(optimizer)
    scaler.update()

    #tqdm loop
    loop.set_postfix(loss = loss.item())

# %%
def get_loaders(
    train_dir,
    train_maskdir,
    val_dir,
    val_maskdir, 
    batch_size,
    train_transform,
    val_transform,
    num_workers = 4,
    pin_memory=True
):
  train_ds = ImageDataset(
      image_dir = train_dir,
      mask_dir = train_maskdir,
      transform = train_transform,
  )

  train_loader = DataLoader(
      train_ds,
      batch_size = batch_size,
      num_workers = num_workers,
      pin_memory = pin_memory,
      shuffle = True,
  )

  val_ds = ImageDataset(
      image_dir = val_dir,
      mask_dir = val_maskdir,
      transform = val_transform,
  )

  val_loader = DataLoader(
    val_ds,
    batch_size = batch_size,
    num_workers = num_workers,
    pin_memory = pin_memory,
    shuffle = False,
  )

  return train_loader, val_loader


def check_accuracy (loader, model, device = 'cuda'):
  num_correct = 0
  num_pixels = 0
  dice_score = 0
  model.eval()

  with torch.no_grad():
    for x, y in loader:
      x = x.to(device)
      y = y.to(device)
      preds = torch.sigmoid (model(x))
      preds = (preds > 0.5).float()
      num_correct += (preds == y).sum()
      num_pixels += torch.numel(preds)
      num_pixels = num_pixels 
      dice_score = (2 * (preds * y).sum() / ((preds + y).sum()))
  
  print (f'Got {num_correct}/{num_pixels}')
  #with accuracy {num_correct/num_pixels*100:.2f}
  print (f'Dice score: {dice_score/(len(loader)+ 1)}')

  model.train()

def save_predictions_as_imgs (loader, model, folder = '/content/sample_data', device = 'cuda'):
  model.eval()
  for idx, (x, y) in enumerate (loader):
    x = x.to (device = device)
    with torch.no_grad():
      preds = torch.sigmoid(model(x))
      preds = (preds > 0.5).float()
      torchvision.utils.save_image(preds, f"{folder}/pred_{idx}.png")
      torchvision.utils.save_image(y.unsqueeze(1), f"{folder}/label_{idx}.png")
    
  model.train()

# %%
def save_checkpoint (state, filename = 'my_checkpoint.pth.tar'):
  print("=> Saving Checkpoint")
  torch.save(state, filename)

# %%
def main():
  train_transform = A.Compose(
      [A.Resize (height = IMAGE_HEIGHT, width = IMAGE_WIDTH),
       A.Rotate (limit=35, p=1.0),
       A.HorizontalFlip (p=0.5),
       A.Normalize(
          mean = [0.0, 0.0, 0.0],
          std = [1.0, 1.0, 1.0],
          max_pixel_value = 255.0,
       ),
       ToTensorV2(),
       ],
  )

  val_transforms = A.Compose(
      [A.Resize (height = IMAGE_HEIGHT, width = IMAGE_WIDTH),
       A.Normalize(
          mean = [0.0, 0.0, 0.0],
          std = [1.0, 1.0, 1.0],
          max_pixel_value = 255.0,
       ),
       ToTensorV2(),
       ],
  )

  model = UNET (in_channels = 3, out_channels = 1).to(DEVICE)
  loss_fn = nn.BCEWithLogitsLoss()
  optimizer = optim.Adam(model.parameters(), lr = LEARNING_RATE)

  train_loader, val_loader = get_loaders(
      TRAIN_IMG_DIR,
      TRAIN_MASK_DIR,
      VAL_IMG_DIR,
      VAL_MASK_DIR,
      BATCH_SIZE,
      train_transform,
      val_transforms,
      NUM_WORKERS,
      PIN_MEMORY
  )

  scaler = torch.cuda.amp.GradScaler()

  for epoch in range(NUM_EPOCHS):
    train_fn(train_loader, model, optimizer, loss_fn, scaler)

    checkpoint =  {"state_dict": model.state_dict(), "optimizer": optimizer.state_dict()}
    save_checkpoint(checkpoint)

    check_accuracy(val_loader, model, device = DEVICE) 

    save_predictions_as_imgs(val_loader, model, folder = '/content/Predictions', device = DEVICE)

# %%
if __name__ == '__main__':
  main()
# Out:
# 100%|██████████| 7/7 [02:57<00:00, 25.35s/it, loss=0.516]
# => Saving Checkpoint
# Got 0/0
# Dice score: 0.0
# 100%|██████████| 7/7 [03:04<00:00, 26.32s/it, loss=-.383]
# => Saving Checkpoint
# Got 0/0
# Dice score: 0.0
# 100%|██████████| 7/7 [03:01<00:00, 25.88s/it, loss=0.682]
# => Saving Checkpoint
# Got 0/0
# Dice score: 0.0
